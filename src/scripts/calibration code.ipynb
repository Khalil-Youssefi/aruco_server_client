# %%
import numpy as np
import cv2
import glob
from matplotlib import pyplot as plt
import yaml

# %%
cx = 4
cy = 7
# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((cx*cy,3), np.float32)
objp[:,:2] = np.mgrid[0:cx,0:cy].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

images = glob.glob('calib/*.jpg')
scs = 0
total = len(images)
checked = 0
for fname in images:
    print(fname)
    checked = checked + 1
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, (cx,cy),None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        corners = np.array([[corner for [corner] in corners]])
        scs = scs + 1
        objpoints.append(objp)

        corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
        imgpoints.append(corners2)

        # Draw and display the corners
        img = cv2.drawChessboardCorners(img, (cx,cy), corners2,ret)
        
    print(fname, checked , '(', scs, ') /', total)
# Out:
# calib/img_56.jpg
# calib/img_56.jpg 1 ( 1 ) / 129
# calib/img_74.jpg
# calib/img_74.jpg 2 ( 1 ) / 129
# calib/img_132.jpg
# calib/img_132.jpg 3 ( 2 ) / 129
# calib/img_60.jpg
# calib/img_60.jpg 4 ( 3 ) / 129
# calib/img_1.jpg
# calib/img_1.jpg 5 ( 4 ) / 129
# calib/img_44.jpg
# calib/img_44.jpg 6 ( 5 ) / 129
# calib/img_125.jpg
# calib/img_125.jpg 7 ( 6 ) / 129
# calib/img_21.jpg
# calib/img_21.jpg 8 ( 7 ) / 129
# calib/img_0.jpg
# calib/img_0.jpg 9 ( 8 ) / 129
# calib/img_11.jpg
# calib/img_11.jpg 10 ( 9 ) / 129
# calib/img_98.jpg
# calib/img_98.jpg 11 ( 9 ) / 129
# calib/img_3.jpg
# calib/img_3.jpg 12 ( 10 ) / 129
# calib/img_19.jpg
# calib/img_19.jpg 13 ( 11 ) / 129
# calib/img_93.jpg
# calib/img_93.jpg 14 ( 11 ) / 129
# calib/img_63.jpg
# calib/img_63.jpg 15 ( 12 ) / 129
# calib/img_84.jpg
# calib/img_84.jpg 16 ( 13 ) / 129
# calib/img_67.jpg
# calib/img_67.jpg 17 ( 13 ) / 129
# calib/img_64.jpg
# calib/img_64.jpg 18 ( 14 ) / 129
# calib/img_27.jpg
# calib/img_27.jpg 19 ( 15 ) / 129
# calib/img_127.jpg
# calib/img_127.jpg 20 ( 16 ) / 129
# calib/img_78.jpg
# calib/img_78.jpg 21 ( 17 ) / 129
# calib/img_83.jpg
# calib/img_83.jpg 22 ( 18 ) / 129
# calib/img_18.jpg
# calib/img_18.jpg 23 ( 19 ) / 129
# calib/img_151.jpg
# calib/img_151.jpg 24 ( 19 ) / 129
# calib/img_7.jpg
# calib/img_7.jpg 25 ( 20 ) / 129
# calib/img_86.jpg
# calib/img_86.jpg 26 ( 21 ) / 129
# calib/img_28.jpg
# calib/img_28.jpg 27 ( 22 ) / 129
# calib/img_69.jpg
# calib/img_69.jpg 28 ( 22 ) / 129
# calib/img_35.jpg
# calib/img_35.jpg 29 ( 23 ) / 129
# calib/img_121.jpg
# calib/img_121.jpg 30 ( 23 ) / 129
# calib/img_43.jpg 104 ( 88 ) / 129
# calib/img_9.jpg
# calib/img_9.jpg 105 ( 89 ) / 129
# calib/img_66.jpg
# calib/img_66.jpg 106 ( 89 ) / 129
# calib/img_129.jpg
# calib/img_129.jpg 107 ( 90 ) / 129
# calib/img_144.jpg
# calib/img_144.jpg 108 ( 91 ) / 129
# calib/img_80.jpg
# calib/img_80.jpg 109 ( 92 ) / 129
# calib/img_92.jpg
# calib/img_92.jpg 110 ( 92 ) / 129
# calib/img_85.jpg
# calib/img_85.jpg 111 ( 93 ) / 129
# calib/img_72.jpg
# calib/img_72.jpg 112 ( 93 ) / 129
# calib/img_58.jpg
# calib/img_58.jpg 113 ( 94 ) / 129
# calib/img_26.jpg
# calib/img_26.jpg 114 ( 95 ) / 129
# calib/img_141.jpg
# calib/img_141.jpg 115 ( 96 ) / 129
# calib/img_133.jpg
# calib/img_133.jpg 116 ( 97 ) / 129
# calib/img_140.jpg
# calib/img_140.jpg 117 ( 98 ) / 129
# calib/img_36.jpg
# calib/img_36.jpg 118 ( 99 ) / 129
# calib/img_4.jpg
# calib/img_4.jpg 119 ( 100 ) / 129
# calib/img_23.jpg
# calib/img_23.jpg 120 ( 101 ) / 129
# calib/img_128.jpg
# calib/img_128.jpg 121 ( 102 ) / 129
# calib/img_138.jpg
# calib/img_138.jpg 122 ( 103 ) / 129
# calib/img_126.jpg
# calib/img_126.jpg 123 ( 104 ) / 129
# calib/img_130.jpg
# calib/img_130.jpg 124 ( 105 ) / 129
# calib/img_37.jpg
# calib/img_37.jpg 125 ( 106 ) / 129
# calib/img_32.jpg
# calib/img_32.jpg 126 ( 107 ) / 129
# calib/img_59.jpg
# calib/img_59.jpg 127 ( 108 ) / 129
# calib/img_54.jpg
# calib/img_54.jpg 128 ( 109 ) / 129
# calib/img_99.jpg
# calib/img_99.jpg 129 ( 109 ) / 129

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)

# transform the matrix and distortion coefficients to writable lists
data = {'camera_matrix': np.asarray(mtx).tolist(),
        'dist_coeff': np.asarray(dist).tolist()}

# and save it to a file
with open("virtual_calibration_matrix.yaml", "w") as f:
    yaml.dump(data, f)

# done

# %%
with open("virtual_calibration_matrix.yaml", 'r') as stream:
    data_loaded = yaml.safe_load(stream)
mtx = np.array(data_loaded['camera_matrix'])
dist = np.array(data_loaded['dist_coeff'])

# %%
img = cv2.imread(np.random.choice(images))
h,  w = img.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),1,(w,h))

dst = cv2.undistort(img, mtx, dist, None, newcameramtx)

x,y,w,h = roi
dst = dst[y:y+h, x:x+w]
plt.figure(figsize=(7,7))
plt.imshow(dst)
plt.figure(figsize=(7,7))
plt.imshow(img)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
newcameramtx
# Out:
# array([[975.74530774,   0.        , 640.19136562],
#        [  0.        , 977.90338057, 359.9640161 ],
#        [  0.        ,   0.        ,   1.        ]])
